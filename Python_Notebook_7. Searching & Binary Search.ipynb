# %% [markdown]
# ## Searching
# ##### Searching means to find out whether a particular element is present in a given sequence or not. There are commonly two types of searching techniques:
# ###### ● Linear search (We have studied about this in Arrays and Lists)
# ###### ● Binary search
#
# ## Binary Search
# #####  Binary Search is a searching algorithm for finding an element's position in a sorted array. In a nutshell, this search algorithm takes advantage of a collection of elements of being already sorted by ignoring half of the elements after just one comparison.
# ##### Prerequisite: Binary search has one pre-requisite; unlike the linear search where elements could be any order, the array in binary search must be sorted.
#
# ####  The algorithm works as follows:
# ######  1. Let the element we are searching for, in the given array/list is X.
# ###### 2. Compare X with the middle element in the array.
# ###### 3. If X matches with the middle element, we return the middle index.
# ###### 4. If X is greater than the middle element, then X can only lie in the right (greater) half subarray after the middle element, then we apply the algorithm again for the right half.
# ###### 5. If X is smaller than the middle element, then X must lie in the left (lower) half, this is because the array is sorted. So we apply the algorithm for the left half.
#
# ![Screenshot%202022-03-20%20214519.png](attachment:Screenshot%202022-03-20%20214519.png)

# %%
#Function to implement Binary Search Algorithm
def binarySearch(array, x, low, high):
    
    #Repeat until the pointers low and high meet each other
    while low <= high:
        mid = low + (high - low) #Middle Index
        if array[mid] == x: #Element Found
            return mid
        elif array[mid] < x: #x is on the right side
            low = mid + 1
        else: #x is on the left side
            high = mid - 1
    return -1 #Element is not found

array = [3, 4, 5, 6, 7, 8, 9]
x = 9

result = binarySearch(array, x, 0, len(array)-1)

if result != -1: #If element is found
    print("Element is present at index " + str(result))
else: #If element is not found
    print("Not found")
# Out:
# Element is present at index 6

# %% [markdown]
# ## Advantages of Binary search:
# ###### ● This searching technique is faster and easier to implement.
# ###### ● Requires no extra space.
# ###### ● Reduces the time complexity of the program to a greater extent. (The term time complexity might be new to you, you will get to understand this when you will be studying algorithmic analysis. For now, just consider it as the time taken by a particular algorithm in its execution, and time complexity is determined by the number of operations that are performed by that algorithm i.e. time complexity is directly proportional to the number of operations in the program).

# %%
def binarySearch(array, x, low, high):
    while low<=high:
        mid = (low + high)//2
        if(array[mid] == x ):
            return mid
        elif(array[mid] < x ):
            low = mid + 1
        else:
            high = mid - 1
    return -1


arr = [1,3,7,9,11,12,45]
x = 3

result = binarySearch(arr, x, 0, len(array)-1)

if result != -1: 
    print("Element is present at index " + str(result))
else: 
    print("Not found")
# Out:
# Element is present at index 1

# %%
def binarySearch(arr, x, low, high):
    for i in range(len(arr)):
        print(x, n, low, high)
        



arr = [1,3,7,9,11,12,45]
x = 3
n= len(arr)
low = 0
high = arr[n-1]
# print(x, n, low, high)
binarySearch(arr, x, low, high)
# Out:
# 3 7 0 45
# 3 7 0 45
# 3 7 0 45
# 3 7 0 45
# 3 7 0 45
# 3 7 0 45
# 3 7 0 45

# %%
def binarySearch(arr, x):
    low = 0
    high = len(arr) - 1
    
    while low <= high:
        mid = (low + high)//2
        if(arr[mid] == x):
            return mid
        elif(arr[mid] < x):
            low = mid + 1
        else:
            high = mid - 1
    return -1

arr = [0,1,3,7,8,10,14,19]
x = 9

result = binarySearch(arr, x)

if (result != -1):
    print("Element is persent at index " + str(result))
else:
    print("Element not found")
# Out:
# Element not found

# %%
def binarySearch(arr, x, debug=False):
    low_bound = 0
    high_bound = len(arr) - 1
    
    while low_bound <= high_bound:
        mid = (low_bound + high_bound)//2
        if debug:
            print("Lower bound", low_bound)
            print("Higher bound", high_bound)
            print("Middle bound", mid)
        if(arr[mid] == x):
            return mid
        elif(arr[mid] < x):
            low_bound = mid + 1
        else:
            high_bound = mid - 1
            
    return "Your element isn't avilable in the given array"


arr = [0,1,3,7,8,10,14,19]
x = 19
binarySearch(arr, x, debug=True)
# Out:
# Lower bound 0
# Higher bound 7
# Middle bound 3
# Lower bound 4
# Higher bound 7
# Middle bound 5
# Lower bound 6
# Higher bound 7
# Middle bound 6
# Lower bound 7
# Higher bound 7
# Middle bound 7
# 7

# %% [markdown]
# ## same value multiple time

# %%
def binarySearch(arr, x, debug=False):
    low_bound = 0
    high_bound = len(arr) - 1
    
    while low_bound <= high_bound:
        mid = (low_bound + high_bound)//2
        if debug:
            print("Lower bound", low_bound)
            print("Higher bound", high_bound)
            print("Middle bound", mid)
        if(arr[mid] == x):
            return mid
        elif(arr[mid] < x):
            low_bound = mid + 1
        else:
            high_bound = mid - 1
            
    return "Your element isn't avilable in the given array"


arr = [0,1,3,7,19,19,19,19,8,10,14,19]
x = 19
binarySearch(arr, x, debug=True)
# Out:
# Lower bound 0
# Higher bound 11
# Middle bound 5
# 5

# %%
def binarySearch(arr, x, debug=False):
    low_bound = 0
    high_bound = len(arr) - 1
    
    while low_bound <= high_bound:
        mid = (low_bound + high_bound)//2
        if debug:
            print("Lower bound", low_bound)
            print("Higher bound", high_bound)
            print("Middle bound", mid)
        if(arr[mid] == x):
            return mid
        elif(arr[mid] < x):
            low_bound  = mid + 1
        else: 
            high_bound = mid - 1

            
    return "Your element isn't avilable in the given array"


arr = [1, 2, 2, 3, 3, 3, 4, 8, 9, 19, 19, 19]
x = 19
x1 =3
binarySearch(arr, x1, debug=True)
# Out:
# Lower bound 0
# Higher bound 11
# Middle bound 5
# 5
